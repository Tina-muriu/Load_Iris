# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
#training the models

# %%
X_train,X_test,y_train,y_test=train_test_split(iris.data,iris.target,random_state=0)

# %%
tree_model=DecisionTreeClassifier()

# %%
tree_model.fit(X_train, y_train)
print("The training dataset accuracy is: {:.2f}".format(tree_model.score(X_train, y_train)))
print("The testing dataset accuracy is: {:.2f}".format(tree_model.score(X_test, y_test)))
# Out:
# The training dataset accuracy is: 1.00
# The testing dataset accuracy is: 0.97

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from sklearn import tree
fig=plt.figure(figsize=(25,15))
tree.plot_tree(tree_model,

               class_names=['setosa','versicolor','virginica'],
               feature_names=iris.feature_names,filled=True)
# Out:
# [Text(558.0, 733.86, 'petal length (cm) <= 2.35\ngini = 0.665\nsamples = 112\nvalue = [37, 34, 41]\nclass = virginica'),
#  Text(418.5, 570.78, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = setosa'),
#  Text(697.5, 570.78, 'petal length (cm) <= 4.95\ngini = 0.496\nsamples = 75\nvalue = [0, 34, 41]\nclass = virginica'),
#  Text(279.0, 407.70000000000005, 'petal width (cm) <= 1.65\ngini = 0.153\nsamples = 36\nvalue = [0, 33, 3]\nclass = versicolor'),
#  Text(139.5, 244.62, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = versicolor'),
#  Text(418.5, 244.62, 'sepal width (cm) <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = virginica'),
#  Text(279.0, 81.54000000000008, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(558.0, 81.54000000000008, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
# ...
